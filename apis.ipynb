# %%
import pandas as pd
import requests

url = "https://api.themoviedb.org/3/tv/top_rated?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJmMzVkMmI2YWI0ZDI1ZDUzYzhiNTNmYTRhZDAxYmUzOSIsInN1YiI6IjY1ODMxYzY2ZTgxMzFkNDE3OGE0YjJjOCIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.eBm7id58-6Lutq21pdKb2_Ri7XKCHxWLAPhClDYa7Ek"
}

response=requests.get(url, headers=headers)
pd.DataFrame(response.json()['results'])
# Out:
#     adult                     backdrop_path                   genre_ids  \
# 0   False  /9faGSFi5jam6pDWGNd0p8JcJgXQ.jpg                    [18, 80]
# 1   False  /rkB4LyZHo1NHXFEDHl9vSD9r1lI.jpg      [16, 18, 10765, 10759]
# 2   False  /4Mt7WHox67uJ1yErwTBFcV8KWgG.jpg             [10759, 35, 16]
# 3   False   /rBF8wVQN8hTWHspVZBlI3h7HZJ.jpg      [16, 35, 10765, 10759]
# 4   False  /kU98MbVVgi72wzceyrEbClZmMFe.jpg          [16, 10759, 10765]
# 5   False  /A6tMQAo6t6eRFCPhsrShmxZLqFB.jpg  [10759, 16, 10765, 35, 18]
# 6   False  /70YdbMELM4b8x8VXjlubymb2bQ0.jpg                 [18, 10751]
# 7   False  /nTvM4mhqNlHIvUkI1gVnW6XP7GG.jpg          [16, 10759, 10765]
# 8   False  /dfmPbyeZZSz3bekeESvMJaH91gS.jpg      [16, 10765, 10759, 18]
# 9   False  /rqbCbjB19amtOtFQbb3K2lgm2zv.jpg          [16, 10765, 10759]
# 10  False  /jsXKG9uppnPrhqFNhImllyCfLhl.jpg                 [10759, 16]
# 11  False  /hPea3Qy5Gd6z4kJLUruBbwAH8Rm.jpg                    [80, 18]
# ...

# %%
data=pd.DataFrame()
for i in range(1,94):
    url = "https://api.themoviedb.org/3/tv/top_rated?language=en-US&page={}".format(i)

    headers = {
        "accept": "application/json",
        "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJmMzVkMmI2YWI0ZDI1ZDUzYzhiNTNmYTRhZDAxYmUzOSIsInN1YiI6IjY1ODMxYzY2ZTgxMzFkNDE3OGE0YjJjOCIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.eBm7id58-6Lutq21pdKb2_Ri7XKCHxWLAPhClDYa7Ek"
    }

    response=requests.get(url, headers=headers)
    df=pd.DataFrame(response.json()['results'])
    data=pd.concat([data,df],ignore_index=True)

# %%
data
# Out:
#       adult                     backdrop_path               genre_ids      id  \
# 0     False  /9faGSFi5jam6pDWGNd0p8JcJgXQ.jpg                [18, 80]    1396
# 1     False  /rkB4LyZHo1NHXFEDHl9vSD9r1lI.jpg  [16, 18, 10765, 10759]   94605
# 2     False  /4Mt7WHox67uJ1yErwTBFcV8KWgG.jpg         [10759, 35, 16]   37854
# 3     False   /rBF8wVQN8hTWHspVZBlI3h7HZJ.jpg  [16, 35, 10765, 10759]   60625
# 4     False  /kU98MbVVgi72wzceyrEbClZmMFe.jpg      [16, 10759, 10765]     246
# ...     ...                               ...                     ...     ...
# 1853  False  /ezGC9MgPqBLkwgszy0ujHFfTyOl.jpg                 [10764]    4551
# 1854  False  /jHF1ys6WjpKpgj3JPTCP65pN96v.jpg             [18, 10765]   90755
# 1855  False  /68xjylXPOclGga7SJ6vhEIHv0ZL.jpg                 [10764]  130392
# 1856  False   /HmKMi8XfmMx3K7nlYL11W526FB.jpg                 [10764]   10160
# 1857  False  /mYegNdFjJeCISA1RDDCKBhKB4Ao.jpg                [16, 35]  126725
#
# ...

# %%
data.to_csv('movies.csv')

# %%
import requests

url = "https://currency-exchange.p.rapidapi.com/exchange"

querystring = {"from":"SGD","to":"MYR","q":"1.0"}

headers = {
	"X-RapidAPI-Key": "b4ef74c772msh712b9c6550d50e1p1531b9jsn73284cb80d38",
	"X-RapidAPI-Host": "currency-exchange.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# 3.497749847
